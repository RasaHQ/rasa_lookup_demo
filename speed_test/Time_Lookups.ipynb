# %%
# %load_ext autoreload
# %autoreload 2
    
import numpy as np
from time import time
from time_train_test import construct_lookup, train_model, evaluate_model, plot_results, print_stats
import matplotlib.pylab as plt

# %%
N = 100
word_length = 10
verbose = True
start_pow = 0    # 10^start_pow  is first point
end_pow = 7      # 10^end_pow    is last point

num_word_distribution = np.logspace(start_pow, end_pow, num=N)
num_words_list = [int(num_word_distribution[i]) for i in range(N)]
num_words_list = list(set(num_words_list))
num_words_list.sort()

t_train = []
t_eval = []
t_total = []

# %%
for count, num_words in enumerate(num_words_list):

    t_tot = time()
    construct_lookup(num_words, word_length)
    
    train_time = train_model()
    eval_time = evaluate_model()
    
    total_time = time() - t_tot

    if verbose:
        print_stats(count, num_words_list, num_words, train_time, eval_time, total_time)
        
    t_train.append(train_time)
    t_eval.append(eval_time)
    t_total.append(total_time)
# Out:
# 1.08 % done
# with 1 words in lookup table:
#     took 4.477763891220093 sec. to train
#     took 2.3846819400787354 sec. to evaluate
#     took 6.8632972240448 sec. total
# 2.15 % done
# with 2 words in lookup table:
#     took 2.242983818054199 sec. to train
#     took 2.1117441654205322 sec. to evaluate
#     took 4.38978910446167 sec. total
# 3.23 % done
# with 3 words in lookup table:
#     took 2.257240056991577 sec. to train
#     took 2.0934760570526123 sec. to evaluate
#     took 4.389238119125366 sec. total
# 4.30 % done
# with 4 words in lookup table:
#     took 2.148289918899536 sec. to train
#     took 2.0894062519073486 sec. to evaluate
#     took 4.271327018737793 sec. total
# 5.38 % done
# with 5 words in lookup table:
#     took 2.148794174194336 sec. to train
#     took 2.0864460468292236 sec. to evaluate
#     took 4.272266864776611 sec. total
# 6.45 % done
# with 7 words in lookup table:
#     took 2.161222219467163 sec. to train
#     took 2.0888571739196777 sec. to evaluate
#     took 4.287156105041504 sec. total
# 7.53 % done
# with 8 words in lookup table:
#     took 2.168301820755005 sec. to train
#     took 2.15963077545166 sec. to evaluate
#     took 4.361856937408447 sec. total
# 8.60 % done
# with 9 words in lookup table:
#     took 2.1490161418914795 sec. to train
#     took 2.0826609134674072 sec. to evaluate
#     took 4.267420768737793 sec. total
# 9.68 % done
# with 11 words in lookup table:
#     took 2.1435017585754395 sec. to train
#     took 2.0867230892181396 sec. to evaluate
#     took 4.26233696937561 sec. total
# 10.75 % done
# with 13 words in lookup table:
#     took 2.1579079627990723 sec. to train
#     took 2.1136677265167236 sec. to evaluate
#     took 4.305928945541382 sec. total
# 11.83 % done
# with 15 words in lookup table:
#     took 2.1551201343536377 sec. to train
#     took 2.0929322242736816 sec. to evaluate
#     took 4.281812906265259 sec. total
# 12.90 % done
# with 18 words in lookup table:
#     took 2.160189151763916 sec. to train
#     took 2.090461015701294 sec. to evaluate
#     took 4.288264989852905 sec. total
# 13.98 % done
# with 22 words in lookup table:
#     took 2.172300100326538 sec. to train
#     took 2.0766961574554443 sec. to evaluate
#     took 4.287652969360352 sec. total
# 15.05 % done
# with 25 words in lookup table:
#     took 2.1632120609283447 sec. to train
#     took 2.1150410175323486 sec. to evaluate
#     took 4.3138909339904785 sec. total
# 16.13 % done
# with 30 words in lookup table:
#     took 2.1482439041137695 sec. to train
#     took 2.097456693649292 sec. to evaluate
#     took 4.2812700271606445 sec. total
# 17.20 % done
# with 35 words in lookup table:
#     took 2.1367411613464355 sec. to train
#     took 2.0560741424560547 sec. to evaluate
#     took 4.227545738220215 sec. total
# 18.28 % done
# with 42 words in lookup table:
#     took 2.130357027053833 sec. to train
#     took 2.05782413482666 sec. to evaluate
#     took 4.222554683685303 sec. total
# 19.35 % done
# with 49 words in lookup table:
#     took 2.102822780609131 sec. to train
#     took 2.125692844390869 sec. to evaluate
#     took 4.268147945404053 sec. total
# 20.43 % done
# with 58 words in lookup table:
#     took 2.1408450603485107 sec. to train
#     took 2.049767017364502 sec. to evaluate
#     took 4.225735902786255 sec. total
# 21.51 % done
# with 68 words in lookup table:
#     took 2.127192974090576 sec. to train
#     took 2.0853888988494873 sec. to evaluate
#     took 4.253626108169556 sec. total
# 22.58 % done
# with 81 words in lookup table:
#     took 2.147145986557007 sec. to train
#     took 2.0746910572052 sec. to evaluate
#     took 4.256170034408569 sec. total
# 23.66 % done
# with 95 words in lookup table:
#     took 2.1130220890045166 sec. to train
#     took 2.0591628551483154 sec. to evaluate
#     took 4.2083580493927 sec. total
# 24.73 % done
# with 112 words in lookup table:
#     took 2.1149911880493164 sec. to train
#     took 2.056678056716919 sec. to evaluate
#     took 4.2083330154418945 sec. total
# 25.81 % done
# with 132 words in lookup table:
#     took 2.1482722759246826 sec. to train
#     took 2.07503080368042 sec. to evaluate
#     took 4.2615180015563965 sec. total
# 26.88 % done
# with 155 words in lookup table:
#     took 2.1136269569396973 sec. to train
#     took 2.0890369415283203 sec. to evaluate
#     took 4.249297142028809 sec. total
# 27.96 % done
# with 183 words in lookup table:
#     took 2.1325602531433105 sec. to train
#     took 2.0627410411834717 sec. to evaluate
#     took 4.229385852813721 sec. total
# 29.03 % done
# with 215 words in lookup table:
#     took 2.1340107917785645 sec. to train
#     took 2.0735909938812256 sec. to evaluate
#     took 4.24583101272583 sec. total
# 30.11 % done
# with 253 words in lookup table:
#     took 2.1276180744171143 sec. to train
#     took 2.0878710746765137 sec. to evaluate
#     took 4.2551538944244385 sec. total
# 31.18 % done
# with 298 words in lookup table:
#     took 2.1961848735809326 sec. to train
#     took 701.0889461040497 sec. to evaluate
#     took 703.3217039108276 sec. total
# 32.26 % done
# with 351 words in lookup table:
#     took 2.5879008769989014 sec. to train
#     took 3.39642071723938 sec. to evaluate
#     took 6.046062707901001 sec. total
# 33.33 % done
# with 413 words in lookup table:
#     took 2.5690371990203857 sec. to train
#     took 2.5176708698272705 sec. to evaluate
#     took 5.123723030090332 sec. total
# 34.41 % done
# with 486 words in lookup table:
#     took 2.1690049171447754 sec. to train
#     took 2.039370059967041 sec. to evaluate
#     took 4.2517759799957275 sec. total
# 35.48 % done
# with 572 words in lookup table:
#     took 2.128308057785034 sec. to train
#     took 2.0603229999542236 sec. to evaluate
#     took 4.2263360023498535 sec. total
# 36.56 % done
# with 673 words in lookup table:
#     took 2.159280300140381 sec. to train
#     took 2.1050031185150146 sec. to evaluate
#     took 4.299396991729736 sec. total
# 37.63 % done
# with 792 words in lookup table:
#     took 2.2660250663757324 sec. to train
#     took 2.0810461044311523 sec. to evaluate
#     took 4.39136004447937 sec. total
# 38.71 % done
# with 932 words in lookup table:
#     took 2.2036659717559814 sec. to train
#     took 2.0574939250946045 sec. to evaluate
#     took 4.301180839538574 sec. total
# 39.78 % done
# with 1097 words in lookup table:
#     took 2.1337788105010986 sec. to train
#     took 2.078065872192383 sec. to evaluate
#     took 4.25926399230957 sec. total
# 40.86 % done
# with 1291 words in lookup table:
#     took 2.162217140197754 sec. to train
#     took 2.1204559803009033 sec. to evaluate
#     took 4.3225672245025635 sec. total
# 41.94 % done
# with 1519 words in lookup table:
#     took 2.190368890762329 sec. to train
#     took 2.065833806991577 sec. to evaluate
#     took 4.298141002655029 sec. total
# 43.01 % done
# with 1788 words in lookup table:
#     took 2.1732521057128906 sec. to train
#     took 2.0712711811065674 sec. to evaluate
#     took 4.287168025970459 sec. total
# 44.09 % done
# with 2104 words in lookup table:
#     took 1907.7655758857727 sec. to train
#     took 2.0985069274902344 sec. to evaluate
#     took 1909.9049360752106 sec. total
# 45.16 % done
# with 2477 words in lookup table:
#     took 2.1844217777252197 sec. to train
#     took 2.077815055847168 sec. to evaluate
#     took 4.307678937911987 sec. total
# 46.24 % done
# with 2915 words in lookup table:
#     took 2.373784065246582 sec. to train
#     took 3.4007771015167236 sec. to evaluate
#     took 5.8303611278533936 sec. total
# 47.31 % done
# with 3430 words in lookup table:
#     took 4.404756784439087 sec. to train
#     took 4.5951087474823 sec. to evaluate
#     took 9.086791038513184 sec. total
# 48.39 % done
# with 4037 words in lookup table:
#     took 5.394662857055664 sec. to train
#     took 5.304200887680054 sec. to evaluate
#     took 10.809122085571289 sec. total
# 49.46 % done
# with 4750 words in lookup table:
#     took 5.883669137954712 sec. to train
#     took 5.580597877502441 sec. to evaluate
#     took 11.585202932357788 sec. total
# 50.54 % done
# with 5590 words in lookup table:
#     took 1207.8386476039886 sec. to train
#     took 3.112009048461914 sec. to evaluate
#     took 1211.0588178634644 sec. total
# 51.61 % done
# with 6579 words in lookup table:
#     took 2.645007848739624 sec. to train
#     took 2.2102057933807373 sec. to evaluate
#     took 4.922787666320801 sec. total
# 52.69 % done
# with 7742 words in lookup table:
#     took 2.664026975631714 sec. to train
#     took 2.220294713973999 sec. to evaluate
#     took 4.949862241744995 sec. total
# 53.76 % done
# with 9111 words in lookup table:
#     took 2.6137709617614746 sec. to train
#     took 2.2111830711364746 sec. to evaluate
#     took 4.898589372634888 sec. total
# 54.84 % done
# with 10722 words in lookup table:
#     took 2.6241888999938965 sec. to train
#     took 2.2285029888153076 sec. to evaluate
#     took 4.929363965988159 sec. total
# 55.91 % done
# with 12618 words in lookup table:
#     took 2.7348530292510986 sec. to train
#     took 2.23653507232666 sec. to evaluate
#     took 5.057700872421265 sec. total
# 56.99 % done
# with 14849 words in lookup table:
#     took 2.749551296234131 sec. to train
#     took 2.1961777210235596 sec. to evaluate
#     took 5.04034686088562 sec. total
# 58.06 % done
# with 17475 words in lookup table:
#     took 2.8229551315307617 sec. to train
#     took 2.2244820594787598 sec. to evaluate
#     took 5.148905992507935 sec. total
# 59.14 % done
# with 20565 words in lookup table:
#     took 2.991657018661499 sec. to train
#     took 2.227940082550049 sec. to evaluate
#     took 5.3399481773376465 sec. total
# 60.22 % done
# with 24201 words in lookup table:
#     took 3.0883841514587402 sec. to train
#     took 2.213677167892456 sec. to evaluate
#     took 5.427419185638428 sec. total
# 61.29 % done
# with 28480 words in lookup table:
#     took 3.280332088470459 sec. to train
#     took 2.245382785797119 sec. to evaluate
#     took 5.66709303855896 sec. total
# 62.37 % done
# with 33516 words in lookup table:
#     took 3.475348949432373 sec. to train
#     took 2.3831241130828857 sec. to evaluate
#     took 6.017546892166138 sec. total
# 63.44 % done
# with 39442 words in lookup table:
#     took 3.8014771938323975 sec. to train
#     took 2.4957642555236816 sec. to evaluate
#     took 6.4995129108428955 sec. total
# 64.52 % done
# with 46415 words in lookup table:
#     took 3.993053913116455 sec. to train
#     took 2.557543992996216 sec. to evaluate
#     took 6.756457090377808 sec. total
# 65.59 % done
# with 54622 words in lookup table:
#     took 4.501960039138794 sec. to train
#     took 2.5422298908233643 sec. to evaluate
#     took 7.338223934173584 sec. total
# 66.67 % done
# with 64280 words in lookup table:
#     took 4.639947891235352 sec. to train
#     took 2.4483160972595215 sec. to evaluate
#     took 7.408238172531128 sec. total
# 67.74 % done
# with 75646 words in lookup table:
#     took 5.03684401512146 sec. to train
#     took 2.5415539741516113 sec. to evaluate
#     took 7.9008567333221436 sec. total
# 68.82 % done
# with 89021 words in lookup table:
#     took 5.577054977416992 sec. to train
#     took 2.5362820625305176 sec. to evaluate
#     took 8.488173723220825 sec. total
# 69.89 % done
# with 104761 words in lookup table:
#     took 6.073574781417847 sec. to train
#     took 2.7238218784332275 sec. to evaluate
#     took 9.237531185150146 sec. total
# 70.97 % done
# with 123284 words in lookup table:
#     took 6.563724994659424 sec. to train
#     took 2.9560840129852295 sec. to evaluate
#     took 10.047408819198608 sec. total
# 72.04 % done
# with 145082 words in lookup table:
#     took 7.2172181606292725 sec. to train
#     took 2.752865791320801 sec. to evaluate
#     took 10.574928045272827 sec. total
# 73.12 % done
# with 170735 words in lookup table:
#     took 8.11714792251587 sec. to train
#     took 2.8758039474487305 sec. to evaluate
#     took 11.667989015579224 sec. total
# 74.19 % done
# with 200923 words in lookup table:
#     took 8.925525903701782 sec. to train
#     took 3.0175881385803223 sec. to evaluate
#     took 12.720915794372559 sec. total
# 75.27 % done
# with 236448 words in lookup table:
#     took 10.160045862197876 sec. to train
#     took 3.1500461101531982 sec. to evaluate
#     took 14.244699716567993 sec. total
# 76.34 % done
# with 278255 words in lookup table:
#     took 11.51107406616211 sec. to train
#     took 3.5303268432617188 sec. to evaluate
#     took 16.11837887763977 sec. total
# 77.42 % done
# with 327454 words in lookup table:
#     took 14.712456941604614 sec. to train
#     took 5.033599853515625 sec. to evaluate
#     took 21.05983304977417 sec. total
# 78.49 % done
# with 385352 words in lookup table:
#     took 15.635418176651001 sec. to train
#     took 3.82545804977417 sec. to evaluate
#     took 21.321011066436768 sec. total
# 79.57 % done
# with 453487 words in lookup table:
#     took 17.33088183403015 sec. to train
#     took 4.170387029647827 sec. to evaluate
#     took 23.227097272872925 sec. total
# 80.65 % done
# with 533669 words in lookup table:
#     took 19.507560968399048 sec. to train
#     took 4.453859090805054 sec. to evaluate
#     took 26.012673139572144 sec. total
# 81.72 % done
# with 628029 words in lookup table:
#     took 22.528693914413452 sec. to train
#     took 4.890980958938599 sec. to evaluate
#     took 29.811110973358154 sec. total
# 82.80 % done
# with 739072 words in lookup table:
#     took 25.7459499835968 sec. to train
#     took 5.3970208168029785 sec. to evaluate
#     took 33.968432903289795 sec. total
# 83.87 % done
# with 869749 words in lookup table:
#     took 339.74064207077026 sec. to train
#     took 6.100660800933838 sec. to evaluate
#     took 349.1774938106537 sec. total
# 84.95 % done
# with 1023531 words in lookup table:
#     took 35.041157245635986 sec. to train
#     took 35.96143698692322 sec. to evaluate
#     took 74.96543526649475 sec. total
# 86.02 % done
# with 1204503 words in lookup table:
#     took 44.678552865982056 sec. to train
#     took 8.060179233551025 sec. to evaluate
#     took 58.18159294128418 sec. total
# 87.10 % done
# with 1417474 words in lookup table:
#     took 51.080288887023926 sec. to train
#     took 9.494205951690674 sec. to evaluate
#     took 65.97271966934204 sec. total
# 88.17 % done
# with 1668100 words in lookup table:
#     took 58.73723793029785 sec. to train
#     took 10.579263925552368 sec. to evaluate
#     took 75.85299396514893 sec. total
# 89.25 % done
# with 1963040 words in lookup table:
#     took 69.57362198829651 sec. to train
#     took 13.467175006866455 sec. to evaluate
#     took 90.73873615264893 sec. total
# 90.32 % done
# with 2310129 words in lookup table:
#     took 81.46764087677002 sec. to train
#     took 15.301815032958984 sec. to evaluate
#     took 105.84682178497314 sec. total
# 91.40 % done
# with 2718588 words in lookup table:
#     took 98.78487086296082 sec. to train
#     took 19.963960647583008 sec. to evaluate
#     took 129.41127800941467 sec. total
# 92.47 % done
# with 3199267 words in lookup table:
#     took 112.77883172035217 sec. to train
#     took 20.325739860534668 sec. to evaluate
#     took 145.59869694709778 sec. total
# 93.55 % done
# with 3764935 words in lookup table:
#     took 127.62064623832703 sec. to train
#     took 23.589370727539062 sec. to evaluate
#     took 165.66419911384583 sec. total
# 94.62 % done
# with 4430621 words in lookup table:
#     took 152.2723650932312 sec. to train
#     took 27.988799810409546 sec. to evaluate
#     took 197.4441180229187 sec. total
# 95.70 % done
# with 5214008 words in lookup table:
#     took 181.14330887794495 sec. to train
#     took 31.96136236190796 sec. to evaluate
#     took 233.56941103935242 sec. total
# 96.77 % done
# with 6135907 words in lookup table:
#     took 207.38591194152832 sec. to train
#     took 37.33163404464722 sec. to evaluate
#     took 268.010559797287 sec. total
# 97.85 % done
# with 7220809 words in lookup table:
#     took 258.35356998443604 sec. to train
#     took 41.187230825424194 sec. to evaluate
#     took 326.7176990509033 sec. total
# 98.92 % done
# with 8497534 words in lookup table:
#     took 324.1324887275696 sec. to train
#     took 63.574891090393066 sec. to evaluate
#     took 4604.019051790237 sec. total
# 100.00 % done
# with 10000000 words in lookup table:
#     took 371.034775018692 sec. to train
#     took 64.17192506790161 sec. to evaluate
#     took 472.97282695770264 sec. total

# %%
print(t_train)
f, ax = plot_results(num_words_list, t_train, t_eval, t_total, plt_times=True)

# %%
f.savefig('img/results.png', dpi = 400)
plt.show()
